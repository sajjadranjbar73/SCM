# %% [markdown]
# ## Line Charts

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# from matplotlib import pyplot as plt
import seaborn as sns

# %%
stock_data = pd.read_csv('stocks.csv')
stock_data
# Out:
#             Date        AAPL         IBM        CSCO        MSFT
# 0     2000-01-03  111.937502  116.000000  108.062500  116.562500
# 1     2000-01-04  102.500003  112.062500  102.000000  112.625000
# 2     2000-01-05  103.999997  116.000000  101.687500  113.812500
# 3     2000-01-06   94.999998  114.000000  100.000000  110.000000
# 4     2000-01-07   99.500001  113.500000  105.875000  111.437500
# ...          ...         ...         ...         ...         ...
# 3516  2013-12-24  567.669975  183.220001   21.690001   37.080002
# 3517  2013-12-26  563.900009  185.350006   21.799999   37.439999
# 3518  2013-12-27  560.089989  185.080002   22.020000   37.290001
# 3519  2013-12-30  554.519981  186.410004   22.250000   37.290001
# 3520  2013-12-31  561.019997  187.570007   22.430000   37.410000
#
# [3521 rows x 5 columns]

# %%
stock_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3521 entries, 0 to 3520
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    3521 non-null   object
#  1   AAPL    3521 non-null   float64
#  2   IBM     3521 non-null   float64
#  3   CSCO    3521 non-null   float64
#  4   MSFT    3521 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 137.7+ KB

# %%
stock_data['Date'] = pd.to_datetime(stock_data['Date'])
stock_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3521 entries, 0 to 3520
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    3521 non-null   datetime64[ns]
#  1   AAPL    3521 non-null   float64
#  2   IBM     3521 non-null   float64
#  3   CSCO    3521 non-null   float64
#  4   MSFT    3521 non-null   float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 137.7 KB

# %%
# stock_data.describe()
stock_data.describe().T
# Out:
#        count        mean         std    min        25%         50%  \
# AAPL  3521.0  169.827774  177.015900  13.12  26.740000   91.809999
# IBM   3521.0  118.820996   39.805120  55.07  87.790001  106.437500
# CSCO  3521.0   24.396787   16.249696   8.60  17.680000   20.389999
# MSFT  3521.0   35.497734   16.922080  15.15  25.900000   28.230000
#
#              75%         max
# AAPL  256.880005  702.100021
# IBM   129.990005  215.800003
# CSCO   24.180000  144.375000
# MSFT   34.700001  116.562500

# %% [markdown]
# ## Plotting with Pandas

# %%
# df.plot(default=line)
stock_data.plot();

# %%
stock_data.plot(kind = 'line', x = 'Date', y ='AAPL');

# %%
stock_data.plot(kind = 'line', 
                x = 'Date', 
                y ='AAPL', 
                color = '#e6acc6' , 
                figsize=(10,6)
               );

# %% [markdown]
# https://www.w3schools.com/colors/colors_names.asp

# %%
stock_data.plot(kind = 'line', 
                x = 'Date', 
                y ='AAPL', 
                color = 'purple' , 
                figsize=(10,6),
                title = 'Stock-Value per Date'
               )
plt.xlabel("Year")
plt.ylabel("Value");

# %%
# df.plot.line()
stock_data.plot(kind = 'line', 
                x = 'Date', 
                y ='AAPL', 
                color = 'Crimson' , 
                figsize=(10,6),
                title = 'Stock-Value per Date',
                yticks = list(range(0,750,50))
               )
plt.xlabel("Year")
plt.ylabel("Value");

# %%
stock_data.plot(kind = 'line', 
                x = 'Date', 
                y =['AAPL','IBM'], 
                color = ['coral','darkgreen'] , 
                figsize = (14,7),
                title = 'Stock-Value per Date',
                yticks = list(range(0,750,50))
               )
plt.xlabel("Year")
plt.ylabel("Value")
plt.show()

# %%
stock_data.plot(kind = 'line', 
                x = 'Date', 
                y =['AAPL','IBM'], 
                color = ['coral','darkgreen'] , 
#                 figsize=(14,7),
                title = 'Stock-Value per Date',
                yticks = list(range(0,750,50))
               )
plt.xlabel("Year")
plt.ylabel("Value")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Plotting with Matplotlib

# %%
# plt.plot(x=stock_data.Date, y=stock_data.MSFT)
plt.plot(stock_data.Date, stock_data.MSFT)
plt.show()

# %%
# When x axis in not set, (Index)
plt.plot(stock_data.MSFT);

# %%
# Plotting multiple lines

plt.plot(stock_data.Date, stock_data.AAPL, label = 'AAPL')
plt.plot(stock_data.Date, stock_data.IBM, label = 'IBM')
plt.legend(loc='upper left')
plt.show()

# %%
plt.plot(stock_data.Date,
         stock_data.MSFT,
         color='Green',
         marker='o',
         linestyle='dashed',
         linewidth=2,
         markersize=12)
plt.show()

# %%
plt.plot(stock_data.Date.iloc[0:10],
         stock_data.MSFT.iloc[0:10],
         color='green',
         marker='s', # p,o,s,h,v,x
         linestyle='dashed',
         linewidth=2,
         markersize=12)
plt.show()

# %%
plt.plot(stock_data.Date.loc[0:10],
         stock_data.MSFT.loc[0:10],
         'gp-.',
         linewidth=2,
         markersize=12)
plt.show()

# %%
plt.plot(stock_data.Date.loc[0:10],
         stock_data.MSFT.loc[0:10],
         'rs-.',
         linewidth=2,
         markersize=12)
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,5))

plt.plot(stock_data.Date.loc[0:10],
         stock_data.MSFT.loc[0:10],
         'rs-.',
         linewidth=2,
         markersize=12)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Creating Subplots

# %%
stock_data_dateindex

# %%
a , b = plt.subplots(2, 2)
# print(type(a))
# print(type(b))
# type(a) = matplotlib.figure
# type(b) = numpy.ndarray

b[0,0].plot(stock_data_dateindex['AAPL'])
b[0,1].plot(stock_data_dateindex['MSFT'])
b[1,0].plot(stock_data_dateindex['IBM'])
b[1,1].plot(stock_data_dateindex['CSCO'])

a.suptitle('Stock Trends')
plt.show()

# %%
fig , axes = plt.subplots(2, 2 , sharey=True)

axes[0,0].plot(stock_data_dateindex['AAPL'])
axes[0,0].set_title('Apple Stock')

axes[0,1].plot(stock_data_dateindex['MSFT'])
axes[0,1].set_title('microsft Stock')

axes[1,0].plot(stock_data_dateindex['IBM'])
axes[1,0].set_title('IBM Stock')

axes[1,1].plot(stock_data_dateindex['CSCO'])
axes[1,1].set_title('Cisco Stock')

fig.suptitle('Stock Trends')
plt.tight_layout()
plt.show()

# %%
# Another way to create subplots
plt.subplots(2,2, sharey='all',sharex='all')

plt.subplot(2,2,1)
plt.plot(stock_data['Date'],stock_data['AAPL'])
plt.title('Apple Stock')

plt.subplot(2,2,2)
plt.plot(stock_data['Date'],stock_data['MSFT'])
plt.title('Microsoft Stock')

plt.subplot(2,2,3)
plt.plot(stock_data['Date'],stock_data['CSCO'])
plt.title('Cisco Stock')

plt.subplot(2,2,4)
plt.plot(stock_data['Date'],stock_data['IBM'])
plt.title('IBM Stock')
  
plt.tight_layout()
plt.show()

# %% [markdown]
# https://matplotlib.org/stable/gallery/subplots_axes_and_figures/subplots_demo.html

# %% [markdown]
# ## Plotting with Seaborn

# %%
stock_data

# %%
sns.lineplot(data = stock_data, x = 'Date', y = 'MSFT', color = 'green')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.lineplot(data = stock_data);

# %%
#Date as index
sns.lineplot(data = stock_data_dateindex)

# %%
sns.lineplot(data = stock_data_dateindex[['AAPL','IBM']]);

# %%
sns.lineplot(data = stock_data_dateindex[['AAPL','IBM']], palette=['b', 'red']);

# %%
# multiple y for each x 
stock_data['Year'] = stock_data.Date.dt.year
plt.figure(figsize=(15,6))
fig = sns.lineplot(data = stock_data , x = 'Year' , y= 'AAPL', ci= 'sd', color = 'b');

# %%
stock_data['Year'] = stock_data.Date.dt.year
plt.figure(figsize=(15,6))
fig = sns.lineplot(data = stock_data , x = 'Year' , y= 'AAPL', color = 'b');

# %%
sns.relplot(data = stock_data , x = 'Year' , y= 'AAPL')
